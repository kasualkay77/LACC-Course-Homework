# %% [markdown]
# <a href="https://colab.research.google.com/github/kasualkay77/Assignment-1-/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [Assignment #1 Project Write up](https://https://docs.google.com/document/d/1TcrrrcG6XkeXRm2Jzty3hbf4I49ppwMtwVIiS0U5rk8/edit?usp=sharing)

# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv', index_col=0)

# %%
df.summary
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-bf61d4a76141> in <module>()
# ----> 1 df.summary
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'summary'

# %%
df.info
# Out:
# <bound method DataFrame.info of                                School Name School Level  \
# School DBN
# 01M034      P.S. 034 Franklin D. Roosevelt          K-8
# 01M034      P.S. 034 Franklin D. Roosevelt          K-8
# 01M034      P.S. 034 Franklin D. Roosevelt          K-8
# 01M140              P.S. 140 Nathan Straus          K-8
# 01M140              P.S. 140 Nathan Straus          K-8
# ...                                    ...          ...
# 84X717                Icahn Charter School          K-8
# 84X717                Icahn Charter School          K-8
# 84X717                Icahn Charter School          K-8
# 84X717                Icahn Charter School          K-8
# 84X717                Icahn Charter School          K-8
#
#                            Regents Exam  Year  Total Tested Mean Score  \
# School DBN
# 01M034              Common Core Algebra  2017             4          s
# 01M034               Living Environment  2015            16       77.9
# ...

# %%
df.head(10)
# Out:
#                                School Name School Level         Regents Exam  \
# School DBN
# 01M034      P.S. 034 Franklin D. Roosevelt          K-8  Common Core Algebra
# 01M034      P.S. 034 Franklin D. Roosevelt          K-8   Living Environment
# 01M034      P.S. 034 Franklin D. Roosevelt          K-8   Living Environment
# 01M140              P.S. 140 Nathan Straus          K-8  Common Core Algebra
# 01M140              P.S. 140 Nathan Straus          K-8  Common Core Algebra
# 01M140              P.S. 140 Nathan Straus          K-8   Living Environment
# 01M140              P.S. 140 Nathan Straus          K-8   Living Environment
# 01M140              P.S. 140 Nathan Straus          K-8   Living Environment
# 01M184                P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 01M184                P.S. 184m Shuang Wen          K-8  Common Core Algebra
#
#             Year  Total Tested Mean Score Number Scoring Below 65  \
# School DBN
# ...

# %%
df.groupby('Regents Exam').agg(['max'])
# Out:
#                                                               School Name  \
#                                                                       max
# Regents Exam
# Algebra2/Trigonometry             Young Women's Leadership School, Queens
# Common Core Algebra               Young Women's Leadership School, Queens
# Common Core Algebra2              Young Women's Leadership School, Queens
# Common Core English               Young Women's Leadership School, Queens
# Common Core Geometry              Young Women's Leadership School, Queens
# English                           Young Women's Leadership School, Queens
# Geometry                          Young Women's Leadership School, Queens
# Global History and Geography      Young Women's Leadership School, Queens
# Integrated Algebra                Young Women's Leadership School, Queens
# Living Environment                Young Women's Leadership School, Queens
# ...

# %%
pd.set_option('display.max_columns', 500)

# %%
list(df.columns)
# Out:
# ['School Name',
#  'School Level',
#  'Regents Exam',
#  'Year',
#  'Total Tested',
#  'Mean Score',
#  'Number Scoring Below 65',
#  'Percent Scoring Below 65',
#  'Number Scoring 65 or Above',
#  'Percent Scoring 65 or Above',
#  'Number Scoring 80 or Above',
#  'Percent Scoring 80 or Above',
#  'Number Scoring CR',
#  'Percent Scoring CR']

# %%
pd.pandas.set_option('display.max_columns', None)

# %%
df2 = df.groupby('Regents Exam')

# %%
df2.groupby('Mean Score').agg(['min','max'])

# %%
df.groupby([])

# %%
df.dtypes
# Out:
# School Name                    object
# School Level                   object
# Regents Exam                   object
# Year                            int64
# Total Tested                    int64
# Mean Score                     object
# Number Scoring Below 65        object
# Percent Scoring Below 65       object
# Number Scoring 65 or Above     object
# Percent Scoring 65 or Above    object
# Number Scoring 80 or Above     object
# Percent Scoring 80 or Above    object
# Number Scoring CR              object
# Percent Scoring CR             object
# dtype: object

# %%
df3 = pd.to_numeric()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-764fb48c0abb> in <module>()
# ----> 1 df['Mean Score'] = pd.to_numeric()
#
# TypeError: to_numeric() missing 1 required positional argument: 'arg'

# %%
#Analyze Student test performance 
#groupby 
#Pick a feature/Measure/core 
#compare above school to a school in your area 
#Schools in a bourough or district 
#The analysis should include some descriptive Statistics 
#the analysis should include on vizualization

# %% [markdown]
# **df**.describe
